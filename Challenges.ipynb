# %%
import requests
import json
import pandas as pd

# %%
token="17eee0fc56d94830028f136a2c442ed1d498b2ee" # I created this token on this website https://github.com/settings/tokens

# %%
api_url = 'https://api.github.com/user'
headers = {'Authorization':"token " + token, 'User-Agent': 'aaronepv'}
response = requests.get(api_url,headers=headers)
rates = json.loads(response.text)
rates
# Out:
# {'login': 'aaronepv',
#  'id': 63072501,
#  'node_id': 'MDQ6VXNlcjYzMDcyNTAx',
#  'avatar_url': 'https://avatars2.githubusercontent.com/u/63072501?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/aaronepv',
#  'html_url': 'https://github.com/aaronepv',
#  'followers_url': 'https://api.github.com/users/aaronepv/followers',
#  'following_url': 'https://api.github.com/users/aaronepv/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/aaronepv/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/aaronepv/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/aaronepv/subscriptions',
#  'organizations_url': 'https://api.github.com/users/aaronepv/orgs',
#  'repos_url': 'https://api.github.com/users/aaronepv/repos',
#  'events_url': 'https://api.github.com/users/aaronepv/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/aaronepv/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Aaron Elias Perez',
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 26,
#  'public_gists': 0,
#  'followers': 0,
#  'following': 0,
#  'created_at': '2020-04-02T19:28:52Z',
#  'updated_at': '2020-08-15T10:50:38Z'}

# %%
repo = requests.get(rates['repos_url']).json() # with this action i could open the repositories

# %%
df_data=pd.DataFrame(repo) # I converted all the data about repositories in a data frame

# %%
df_data
# Out:
#            id                           node_id  \
# 0   273698363  MDEwOlJlcG9zaXRvcnkyNzM2OTgzNjM=
# 1   274131492  MDEwOlJlcG9zaXRvcnkyNzQxMzE0OTI=
# 2   274471810  MDEwOlJlcG9zaXRvcnkyNzQ0NzE4MTA=
# 3   274472649  MDEwOlJlcG9zaXRvcnkyNzQ0NzI2NDk=
# 4   274473004  MDEwOlJlcG9zaXRvcnkyNzQ0NzMwMDQ=
# 5   274478325  MDEwOlJlcG9zaXRvcnkyNzQ0NzgzMjU=
# 6   277176762  MDEwOlJlcG9zaXRvcnkyNzcxNzY3NjI=
# 7   278202937  MDEwOlJlcG9zaXRvcnkyNzgyMDI5Mzc=
# 8   278440562  MDEwOlJlcG9zaXRvcnkyNzg0NDA1NjI=
# 9   278439931  MDEwOlJlcG9zaXRvcnkyNzg0Mzk5MzE=
# 10  278859427  MDEwOlJlcG9zaXRvcnkyNzg4NTk0Mjc=
# 11  278859620  MDEwOlJlcG9zaXRvcnkyNzg4NTk2MjA=
# 12  278859759  MDEwOlJlcG9zaXRvcnkyNzg4NTk3NTk=
# 13  282462260  MDEwOlJlcG9zaXRvcnkyODI0NjIyNjA=
# 14  280480406  MDEwOlJlcG9zaXRvcnkyODA0ODA0MDY=
# 15  283325834  MDEwOlJlcG9zaXRvcnkyODMzMjU4MzQ=
# 16  284247868  MDEwOlJlcG9zaXRvcnkyODQyNDc4Njg=
# 17  284247996  MDEwOlJlcG9zaXRvcnkyODQyNDc5OTY=
# 18  284248168  MDEwOlJlcG9zaXRvcnkyODQyNDgxNjg=
# 19  284248340  MDEwOlJlcG9zaXRvcnkyODQyNDgzNDA=
# 20  259686550  MDEwOlJlcG9zaXRvcnkyNTk2ODY1NTA=
# 21  274415901  MDEwOlJlcG9zaXRvcnkyNzQ0MTU5MDE=
# 22  277598420  MDEwOlJlcG9zaXRvcnkyNzc1OTg0MjA=
# 23  280233906  MDEwOlJlcG9zaXRvcnkyODAyMzM5MDY=
# 24  284250367  MDEwOlJlcG9zaXRvcnkyODQyNTAzNjc=
# 25  272972935  MDEwOlJlcG9zaXRvcnkyNzI5NzI5MzU=
#
#                                         name  \
# 0                 01-lab-list-comprehensions
# 1                      02-lab-tuple-set-dict
# 2              03-lab-functional-programming
# 3                    04-lab-lambda-functions
# 4         05-lab-object-oriented-programming
# 5                      06-lab-error-handling
# 6                   06-lab-map-reduce-filter
# 7                      07-lab-error-handling
# 8                       08-lab-import-export
# 9                   09-lab-string-operations
# 10                     10-lab-advanced-regex
# 11                              11-lab-numpy
# 12                             12-lab-pandas
# 13               13-lab-pandas-data-cleaning
# 14  14-lab-df-calculation-and-transformation
# 15                   15-lab-parsing-API-data
# 16                          16-lab-rss-feeds
# 17                      17-lab-API-scavenger
# 18                       18-lab-web-scraping
# 19              19-lab-advanced-web-scraping
# 20                              data-prework
# 21                               dataV2-labs
# 22                       PR01-project-python
# 23                       PR02-project-pandas
# 24                          PR03-project-web
# 25                              Prueba-Aaron
#
#                                             full_name  private  \
# 0                 aaronepv/01-lab-list-comprehensions    False
# 1                      aaronepv/02-lab-tuple-set-dict    False
# 2              aaronepv/03-lab-functional-programming    False
# 3                    aaronepv/04-lab-lambda-functions    False
# 4         aaronepv/05-lab-object-oriented-programming    False
# 5                      aaronepv/06-lab-error-handling    False
# 6                   aaronepv/06-lab-map-reduce-filter    False
# 7                      aaronepv/07-lab-error-handling    False
# 8                       aaronepv/08-lab-import-export    False
# 9                   aaronepv/09-lab-string-operations    False
# 10                     aaronepv/10-lab-advanced-regex    False
# 11                              aaronepv/11-lab-numpy    False
# 12                             aaronepv/12-lab-pandas    False
# 13               aaronepv/13-lab-pandas-data-cleaning    False
# 14  aaronepv/14-lab-df-calculation-and-transformation    False
# 15                   aaronepv/15-lab-parsing-API-data    False
# 16                          aaronepv/16-lab-rss-feeds    False
# 17                      aaronepv/17-lab-API-scavenger    False
# 18                       aaronepv/18-lab-web-scraping    False
# 19              aaronepv/19-lab-advanced-web-scraping    False
# 20                              aaronepv/data-prework    False
# 21                               aaronepv/dataV2-labs    False
# 22                       aaronepv/PR01-project-python    False
# 23                       aaronepv/PR02-project-pandas    False
# 24                          aaronepv/PR03-project-web    False
# 25                              aaronepv/Prueba-Aaron    False
#
#                                                 owner  \
# 0   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 1   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 2   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 3   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 4   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 5   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 6   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 7   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 8   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 9   {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 10  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 11  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 12  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 13  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 14  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 15  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 16  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 17  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 18  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 19  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 20  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 21  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 22  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 23  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 24  {'login': 'aaronepv', 'id': 63072501, 'node_id...
# 25  {'login': 'aaronepv', 'id': 63072501, 'node_id...
#
#                                              html_url  \
# 0   https://github.com/aaronepv/01-lab-list-compre...
# 1   https://github.com/aaronepv/02-lab-tuple-set-dict
# 2   https://github.com/aaronepv/03-lab-functional-...
# 3   https://github.com/aaronepv/04-lab-lambda-func...
# 4   https://github.com/aaronepv/05-lab-object-orie...
# 5   https://github.com/aaronepv/06-lab-error-handling
# 6   https://github.com/aaronepv/06-lab-map-reduce-...
# 7   https://github.com/aaronepv/07-lab-error-handling
# 8    https://github.com/aaronepv/08-lab-import-export
# 9   https://github.com/aaronepv/09-lab-string-oper...
# 10  https://github.com/aaronepv/10-lab-advanced-regex
# 11           https://github.com/aaronepv/11-lab-numpy
# 12          https://github.com/aaronepv/12-lab-pandas
# 13  https://github.com/aaronepv/13-lab-pandas-data...
# 14  https://github.com/aaronepv/14-lab-df-calculat...
# 15  https://github.com/aaronepv/15-lab-parsing-API...
# 16       https://github.com/aaronepv/16-lab-rss-feeds
# 17   https://github.com/aaronepv/17-lab-API-scavenger
# 18    https://github.com/aaronepv/18-lab-web-scraping
# 19  https://github.com/aaronepv/19-lab-advanced-we...
# 20           https://github.com/aaronepv/data-prework
# 21            https://github.com/aaronepv/dataV2-labs
# 22    https://github.com/aaronepv/PR01-project-python
# 23    https://github.com/aaronepv/PR02-project-pandas
# 24       https://github.com/aaronepv/PR03-project-web
# 25           https://github.com/aaronepv/Prueba-Aaron
#
#                       description   fork  \
# 0                            None   True
# 1                            None   True
# 2                            None   True
# 3                            None   True
# 4                            None   True
# 5                            None  False
# 6                            None   True
# 7                            None   True
# 8                            None   True
# 9                            None   True
# 10                           None   True
# 11                           None   True
# 12                           None   True
# 13                           None   True
# 14                           None   True
# 15                           None   True
# 16                           None   True
# 17                           None   True
# 18                           None   True
# 19                           None   True
# 20                           None   True
# 21                           None   True
# 22  First project of the Module 1   True
# 23                           None   True
# 24                           None   True
# 25            Prueba Aaron de Git  False
#
#                                                   url  ... forks_count  \
# 0   https://api.github.com/repos/aaronepv/01-lab-l...  ...           0
# 1   https://api.github.com/repos/aaronepv/02-lab-t...  ...           0
# 2   https://api.github.com/repos/aaronepv/03-lab-f...  ...           0
# 3   https://api.github.com/repos/aaronepv/04-lab-l...  ...           0
# 4   https://api.github.com/repos/aaronepv/05-lab-o...  ...           0
# 5   https://api.github.com/repos/aaronepv/06-lab-e...  ...           0
# 6   https://api.github.com/repos/aaronepv/06-lab-m...  ...           0
# 7   https://api.github.com/repos/aaronepv/07-lab-e...  ...           0
# 8   https://api.github.com/repos/aaronepv/08-lab-i...  ...           0
# 9   https://api.github.com/repos/aaronepv/09-lab-s...  ...           0
# 10  https://api.github.com/repos/aaronepv/10-lab-a...  ...           0
# 11  https://api.github.com/repos/aaronepv/11-lab-n...  ...           0
# 12  https://api.github.com/repos/aaronepv/12-lab-p...  ...           0
# 13  https://api.github.com/repos/aaronepv/13-lab-p...  ...           0
# 14  https://api.github.com/repos/aaronepv/14-lab-d...  ...           0
# 15  https://api.github.com/repos/aaronepv/15-lab-p...  ...           0
# 16  https://api.github.com/repos/aaronepv/16-lab-r...  ...           0
# 17  https://api.github.com/repos/aaronepv/17-lab-A...  ...           0
# 18  https://api.github.com/repos/aaronepv/18-lab-w...  ...           0
# 19  https://api.github.com/repos/aaronepv/19-lab-a...  ...           0
# 20  https://api.github.com/repos/aaronepv/data-pre...  ...           0
# 21  https://api.github.com/repos/aaronepv/dataV2-labs  ...           0
# 22  https://api.github.com/repos/aaronepv/PR01-pro...  ...           0
# 23  https://api.github.com/repos/aaronepv/PR02-pro...  ...           0
# 24  https://api.github.com/repos/aaronepv/PR03-pro...  ...           0
# 25  https://api.github.com/repos/aaronepv/Prueba-A...  ...           0
#
#    mirror_url archived disabled open_issues_count  \
# 0        None    False    False                 0
# 1        None    False    False                 0
# 2        None    False    False                 0
# 3        None    False    False                 0
# 4        None    False    False                 0
# 5        None    False    False                 0
# 6        None    False    False                 0
# 7        None    False    False                 0
# 8        None    False    False                 0
# 9        None    False    False                 0
# 10       None    False    False                 0
# 11       None    False    False                 0
# 12       None    False    False                 0
# 13       None    False    False                 0
# 14       None    False    False                 0
# 15       None    False    False                 0
# 16       None    False    False                 0
# 17       None    False    False                 0
# 18       None    False    False                 0
# 19       None    False    False                 0
# 20       None    False    False                 0
# 21       None    False    False                 0
# 22       None    False    False                 0
# 23       None    False    False                 0
# 24       None    False    False                 0
# 25       None    False    False                 0
#
#                                               license forks open_issues  \
# 0                                                None     0           0
# 1                                                None     0           0
# 2                                                None     0           0
# 3                                                None     0           0
# 4                                                None     0           0
# 5                                                None     0           0
# 6                                                None     0           0
# 7                                                None     0           0
# 8                                                None     0           0
# 9                                                None     0           0
# 10                                               None     0           0
# 11                                               None     0           0
# 12                                               None     0           0
# 13                                               None     0           0
# 14                                               None     0           0
# 15                                               None     0           0
# 16                                               None     0           0
# 17                                               None     0           0
# 18                                               None     0           0
# 19                                               None     0           0
# 20                                               None     0           0
# 21                                               None     0           0
# 22                                               None     0           0
# 23                                               None     0           0
# 24                                               None     0           0
# 25  {'key': 'lgpl-3.0', 'name': 'GNU Lesser Genera...     0           0
#
#    watchers default_branch
# 0         0         master
# 1         0         master
# 2         0         master
# 3         0         master
# 4         0         master
# 5         0         master
# 6         0         master
# 7         0         master
# 8         0         master
# 9         0         master
# 10        0         master
# 11        0         master
# 12        0         master
# 13        0         master
# 14        0         master
# 15        0         master
# 16        0         master
# 17        0         master
# 18        0         master
# 19        0         master
# 20        0         master
# 21        0         master
# 22        0         master
# 23        0         master
# 24        0         master
# 25        0         master
#
# [26 rows x 73 columns]

# %%
df_data.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
#        'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count',
#        'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license',
#        'forks', 'open_issues', 'watchers', 'default_branch'],
#       dtype='object')

# %% [markdown]
# ## Challenge 1: Fork Languages
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 1. Loop the JSON response to find out the `language` attribute of each fork. Use an array to store the `language` attributes of each fork.
#     * *Hint: Each language should appear only once in your array.*
#
# 1. Print the language array. It should be something like:
#
#   ```["Python", "Jupyter Notebook", "HTML"]```
#
# Again, the documentation of Github API is [here](https://developer.github.com/v3/).

# %%
df_data["language"].value_counts() # Here are the languages in my repositorie
# Out:
# Jupyter Notebook    20
# HTML                 1
# Name: language, dtype: int64

# %%
df_data[["name","fork","language"]]
# Out:
#                                         name   fork          language
# 0                 01-lab-list-comprehensions   True  Jupyter Notebook
# 1                      02-lab-tuple-set-dict   True  Jupyter Notebook
# 2              03-lab-functional-programming   True              HTML
# 3                    04-lab-lambda-functions   True  Jupyter Notebook
# 4         05-lab-object-oriented-programming   True  Jupyter Notebook
# 5                      06-lab-error-handling  False  Jupyter Notebook
# 6                   06-lab-map-reduce-filter   True  Jupyter Notebook
# 7                      07-lab-error-handling   True  Jupyter Notebook
# 8                       08-lab-import-export   True  Jupyter Notebook
# 9                   09-lab-string-operations   True  Jupyter Notebook
# 10                     10-lab-advanced-regex   True  Jupyter Notebook
# 11                              11-lab-numpy   True              None
# 12                             12-lab-pandas   True  Jupyter Notebook
# 13               13-lab-pandas-data-cleaning   True  Jupyter Notebook
# 14  14-lab-df-calculation-and-transformation   True  Jupyter Notebook
# 15                   15-lab-parsing-API-data   True  Jupyter Notebook
# 16                          16-lab-rss-feeds   True  Jupyter Notebook
# 17                      17-lab-API-scavenger   True              None
# 18                       18-lab-web-scraping   True              None
# 19              19-lab-advanced-web-scraping   True              None
# 20                              data-prework   True  Jupyter Notebook
# 21                               dataV2-labs   True              None
# 22                       PR01-project-python   True  Jupyter Notebook
# 23                       PR02-project-pandas   True  Jupyter Notebook
# 24                          PR03-project-web   True  Jupyter Notebook
# 25                              Prueba-Aaron  False  Jupyter Notebook

# %% [markdown]
# ### Challenge 2: Count Commits
#
# Count how many commits were made in the past week.
#
# 1. Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# 1. Count how many commit objects are contained in the array.

# %% [markdown]
# ### Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain `.scavengerhunt` and they are scattered in different directories of this repo. The secret files are named from `.0001.scavengerhunt` to `.0024.scavengerhunt`. They are scattered randomly throughout this repo. You need to **search for these files by calling the Github API**, not searching the local files on your computer.
#
# Notes:
#
# * Github API documentation can be found [here](https://developer.github.com/v3/).
#
# * You will need to study the Github API documentation to decide which API endpoint to call and what parameters to use in order to obtain the information you need. Unless you are already super familiar with Github API or super lucky, you probably will do some trials and errors. Therefore, be prepared to go back and forth in studying the API documentation, testing, and revising until you obtain what you need.
#
# * After receiving the JSON data object, you need to inspect its structure and decide how to parse the data.
#
# * When you test your requests with Github API, sometimes you may be blocked by Github with an error message that reads:
#
#   > You have triggered an abuse detection mechanism and have been temporarily blocked from content creation. Please retry your request again later.
#
#   Don't worry. Check the parameters in your request and wait for a minute or two before you make additional requests.
#
# **After you find out the secrete files:**
#
# 1. Sort the filenames ascendingly.
#
# 1. Read the content of each secret files into an array of strings.
#
# 1. Concatenate the strings in the array separating each two with a whitespace.
#
# 1. Print out the joke.
