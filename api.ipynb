# %%
import requests

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:94.0) Gecko/20100101 Firefox/94.0'}

# %% [markdown]
# # Challenge 1

# %%
url_repos ='https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'

# %%
resp = requests.get(url_repos, headers=headers)

# %%
resp.request.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:94.0) Gecko/20100101 Firefox/94.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
resp.ok
# Out:
# False

# %%
languages=[]
for el in resp.json():
    languages.append(requests.get(el['languages_url'],headers=headers).json())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-44b3416c24a4> in <module>
#       1 languages=[]
#       2 for el in resp.json():
# ----> 3     languages.append(requests.get(el['languages_url'],headers=headers).json())
#
# TypeError: string indices must be integers

# %%
languages
# Out:
# []

# %%
lang_array=[]
for dic in languages:
    lang_array.append(list(dic.keys()))

# %%
lang=[]
for el in lang_array:
    for l in el:
        lang.append(l)

# %%
languages_set=set(lang)

# %%
languages_set
# Out:
# set()

# %% [markdown]
# # Challenge 2

# %%
import pandas as pd

# %%
url_com = 'https://api.github.com/repos/luisbang/mad-oct-2018/commits'

# %%
resp2=requests.get(url_com,headers=headers)

# %%
i=0
commits =[]
for rp in resp2.json():
    dcc={
        'name':resp2.json()[i]['commit']['committer']['name'],
        'date':resp2.json()[i]['commit']['committer']['date'],
        'url':resp2.json()[i]['commit']['tree']['url']
    }
    commits.append(dcc)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-96b8fc9330b0> in <module>
#       3 for rp in resp2.json():
#       4     dcc={
# ----> 5         'name':resp2.json()[i]['commit']['committer']['name'],
#       6         'date':resp2.json()[i]['commit']['committer']['date'],
#       7         'url':resp2.json()[i]['commit']['tree']['url']
#
# KeyError: 0

# %%
resp2.json()[0]['commit']['committer']
# Out:
# {'name': 'Marc Pomar',
#  'email': 'marc@faable.com',
#  'date': '2019-08-19T11:11:36Z'}

# %%
com_df = pd.DataFrame(commits)

# %%
com_df['url'].count()
# Out:
# 30

# %%
type(com_df['date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Challenge 3

# %%
url3='https://api.github.com/repos/ironhack-datalabs/scavenger'

# %%
rep3 = requests.get(url3, headers=headers)

# %%
rep3.json()
# Out:
# {'id': 162375181,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#  'name': 'scavenger',
#  'full_name': 'ironhack-datalabs/scavenger',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
# probamos este url
contents_url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/'

# %%
resp_cont = requests.get(contents_url)

# %%
cont_df = pd.DataFrame(resp_cont.json())

# %%
cont_df
# Out:
#           name        path                                       sha  size  \
# 0   .gitignore  .gitignore  e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf    10
# 1        15024       15024  2945e51c87ad5da893c954afcf092f06343bbb7d     0
# 2        15534       15534  5af6f2a7287e4191f39e55693fc1e9c8918d1d3a     0
# 3        17020       17020  9c49f920aa4d9433fa99a5824128f0e6b90ec5f2     0
# 4        30351       30351  c488d7f64088c852e22067d48fdc64ee3670f3ba     0
# 5        40303       40303  30193d9cf62b07bcbb6366513ff03596861f2d29     0
# 6        44639       44639  22fc3d5c2db80822c351edb2248f3491c8ebda86     0
# 7        45525       45525  6a4a88cd9084110c8646c3cfd84dfe96b300a4a7     0
# 8        47222       47222  c7001604cdadc2fe7b82e0f6996690718cac6941     0
# 9        47830       47830  f84882ad7560fd2b8c6a0867bc707ce9009ef288     0
# 10       49418       49418  46bc658c09589d9023246b00e848ce97d30d4989     0
# ...

# %%
content_df.loc[1,'url']
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024?ref=master'

# %%
arch = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024?ref=master')

# %%
arch.ok
# Out:
# True

# %%
arch.json()
# Out:
# [{'name': '.0006.scavengerhunt',
#   'path': '15024/.0006.scavengerhunt',
#   'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#   'size': 3,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
arch_list = []

for i in content_df['url']:
    json = requests.get(i).json()
    arch_list.append(json)

# %%
# eliminamos el gitignore
del arch_list[0]

# %%
arch_list
# Out:
# [[{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#    'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#    'type': 'file',
#    '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#     'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#     'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
# guardamos los nombres en una lista 
url_list = []
for i in arch_list:
    url_list.append(requests.get(i[0]['url']).json()['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-237040fd236c> in <module>
#       2 url_list = []
#       3 for i in arch_list:
# ----> 4     url_list.append(requests.get(i[0]['url']).json()['name'])
#
# KeyError: 'name'
